# %%
# %run setup.ipynb

# %%
# cartella dove ci sono i dati da analizzare
folder = "setup_dati/"

# importo dati
df_all = pd.read_csv(folder+"df_all_data.csv", sep=',').drop(columns=['Unnamed: 0'])
df_all["doc_index"] = df_all["doc_index"].apply(str)

# %%
df_all["doc_statement_text"].unique()
# Out:
# array(['The Obama administration issued an "11th-hour rule that entrenches federal family planning funding for Planned Parenthood."',
#        'â\x80\x9cWeâ\x80\x99ve got a parole board right now that has released 20 cop killers in the last two years under Hochul.â\x80\x9d',
#        'Says Sens. Lisa Murkowski, Susan Collins and Mitt Romney â\x80\x9care pro-pedophile.â\x80\x9d',
#        'Says U.S. Sen. Ron Johnson, his prospective opponent, has received $1.2 million from the gun lobby.',
#        '"Kathleen Peters refuses to â\x80\x98take a standâ\x80\x99 to repeal Obamacare."',
#        'Members of Congress did not have three days to read the bill "when the stimulus was rushed into law."',
#        'â\x80\x9cThe student debt that is out there, almost 60% of it is graduate school debt.â\x80\x9d',
#        'The 2020 election â\x80\x9cwas stolen from Donald J. Trump.â\x80\x9d',
# ...

# %%
df_tapu = pd.read_csv("../TESI TAPU/FailureAnalysis-main/FailureAnalysis-main/First grouping/Dati/all_rows.csv", sep=',')

# %%
df_tapu["doc_statement"].unique().tolist()
# Out:
# ['The Labor Party has repeatedly claimed the Coalition needs to make cuts of 70 billion to vital services to balance the budget',
#  'Were very prepared to put out a statement before the election updating on the budget process Joshs party hasnt even submitted one policy for costing yet to the Parliamentary Budget Office',
#  'We left the country with net assets of 70 billion where if we are elected on the 7th of September we inherit debt going to 400 billion',
#  'Anthony Albanese says eight out of the worlds top 10 airlines are majority governmentowned',
#  'Tony Abbott says asylum seekers who come to Australia are attempting to break Australian law',
#  'Says the Wisconsin Republican Party tweeted Happy International Womens Day You ladies should get paid less and not be able to make health care decisions',
#  'Says Barack Obama sold Chrysler to Italians who are going to build Jeeps in China at the cost of American jobs',
# ...
