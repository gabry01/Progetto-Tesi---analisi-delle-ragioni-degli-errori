# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns

# %%
folder = "../setup_dati/"

# %%
df = pd.read_csv(folder+"stripped_df.csv", sep=',')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#                   worker_id  paid                   task_id     batch_name  \
# 0  55b645b1fdf99b1c02906872  True  FakeNewsMultidimensional  V4-Prolific-1
# 1  55b645b1fdf99b1c02906872  True  FakeNewsMultidimensional  V4-Prolific-1
# 2  55b645b1fdf99b1c02906872  True  FakeNewsMultidimensional  V4-Prolific-1
# 3  55ca03e1fdf99b2735fc1dde  True  FakeNewsMultidimensional  V4-Prolific-1
# 4  55ca03e1fdf99b2735fc1dde  True  FakeNewsMultidimensional  V4-Prolific-1
#
#     unit_id  try_last  try_current  action                    time_submit  \
# 0  unit_145         1            1    Next  Tue, 23 Aug 2022 12:02:59 GMT
# 1  unit_145         1            1    Next  Tue, 23 Aug 2022 12:06:48 GMT
# 2  unit_145         1            1    Next  Tue, 23 Aug 2022 12:14:46 GMT
# 3   unit_40         1            1  Finish  Tue, 23 Aug 2022 14:10:44 GMT
# 4   unit_40         1            1    Next  Tue, 23 Aug 2022 14:02:01 GMT
#
#           time_submit_parsed  ...  doc_time_elapsed doc_time_start  \
# ...

# %% [markdown]
# seleziono le colonne da mantenere per l'analisiche faremo di seguito

# %%
columns_to_mantain = ["unit_id", 
                      "doc_fact_check_source",
                      "doc_index", 
                      "doc_id", 
                      "doc_statement_text",
                      "doc_statement_description", 
                      "doc_fact_check_ground_truth_label", 
                      "doc_fact_check_ground_truth_value", 
                      "doc_truthfulness_label",
                      "doc_truthfulness_index",
                      "doc_speaker_name",
                      "doc_speaker_party",
                      "doc_evidence_url",
                      "doc_completeness_index",
                      "doc_comprehensibility_index",
                      "doc_informativeness_index",
                      "doc_unbiasedness_index",
                      "doc_accuracy_index",
                      "doc_speaker's-trustworthiness_index",
                      "doc_confidence_index",
                      "doc_time_elapsed",
                      "worker_id"]

# %% [markdown]
# suddivido i df in sotto df

# %%
df_true = df[df["doc_fact_check_ground_truth_label"] == "true"]
df_false = df[df["doc_fact_check_ground_truth_label"] == "pants-on-fire"]

# %%
df_wrong_false = df[df["quartile"] == "wrong_false"]
df_correct_false = df[df["quartile"] == "correct_false"]
df_wrong_true = df[df["quartile"] == "wrong_true"]
df_correct_true = df[df["quartile"] == "correct_true"]

# %% [markdown]
# # Rapporto tra frequenze relative
